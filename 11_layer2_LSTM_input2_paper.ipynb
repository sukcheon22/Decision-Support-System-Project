# %% [markdown]
# ### LSTM - Input: 'Close/Last', 'SMA', 'MACD', 'Signal_Line', 'RSI'

# %%
import pandas as pd
import numpy as np
# Load the data
data = pd.read_csv("Data_input_2.csv")

# Check for missing values
print(data.isnull().sum())

# Fill missing values or drop rows with missing values
data.fillna(method='ffill', inplace=True)  # forward fill
data.dropna(inplace=True)  # drop any remaining NaNs
# Out:
# Date           0
# Close/Last     0
# SMA            0
# MACD           0
# Signal_Line    0
# RSI            0
# dtype: int64
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16020\2442476927.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)  # forward fill

# %%
data['Date'] = pd.to_datetime(data['Date'])

# Tạo các cột phụ để sắp xếp theo năm, tháng, ngày
data['Year'] = data['Date'].dt.year
data['Month'] = data['Date'].dt.month
data['Day'] = data['Date'].dt.day

# Sắp xếp DataFrame theo năm, sau đó tháng, và cuối cùng là ngày
data.sort_values(['Year', 'Month', 'Day'], inplace=True)

# Xóa các cột phụ nếu không cần thiết
data.drop(columns=['Year', 'Month', 'Day'], inplace=True)
data
# Out:
#            Date  Close/Last         SMA        MACD  Signal_Line        RSI
# 1238 2019-06-28     4660.72   4481.3010   99.321197    90.056725  61.707838
# 1237 2019-07-01     4766.31   4511.1155  109.460715    93.937523  67.217516
# 1236 2019-07-02     4747.96   4532.4645  114.693548    98.088728  71.051746
# 1235 2019-07-03     4773.91   4554.6995  119.556383   102.382259  71.499561
# 1234 2019-07-05     4757.68   4573.8110  120.709130   106.047633  77.083139
# ...         ...         ...         ...         ...          ...        ...
# 4    2024-05-23    10495.82  10181.2985  126.992633    71.836167  76.381399
# 3    2024-05-24    10549.22  10205.9780  132.541316    83.977197  74.341863
# 2    2024-05-28    10526.85  10230.3385  133.593631    93.900484  75.571463
# 1    2024-05-29    10396.40  10257.8745  122.489392    99.618265  66.767226
# 0    2024-05-30    10205.24  10283.5305   97.144368    99.123486  57.155972
#
# [1239 rows x 6 columns]

# %%
# Tính toán số lượng dòng cho từng phần
total_rows = len(data)
train_size = int(0.8 * total_rows)
val_size = int(0.1 * total_rows)
test_size = total_rows - train_size - val_size  # Đảm bảo rằng tổng số dòng vẫn bằng total_rows

# Chia DataFrame thành các tập huấn luyện, kiểm tra và kiểm định
data_train = data.iloc[:train_size]
data_val = data.iloc[train_size:train_size + val_size]
data_test = data.iloc[train_size + val_size:]

# %%
data_test
# Out:
#           Date  Close/Last         SMA        MACD  Signal_Line        RSI
# 124 2023-11-30     8850.47   8446.9190  223.476728   190.663496  85.516973
# 123 2023-12-01     8878.94   8498.9565  225.769427   197.684682  81.707888
# 122 2023-12-04     8767.82   8538.4995  216.128557   201.373457  75.088187
# 121 2023-12-05     8749.09   8578.6210  204.618034   202.022373  63.355566
# 120 2023-12-06     8686.94   8607.7955  188.310154   199.279929  57.462766
# ..         ...         ...         ...         ...          ...        ...
# 4   2024-05-23    10495.82  10181.2985  126.992633    71.836167  76.381399
# 3   2024-05-24    10549.22  10205.9780  132.541316    83.977197  74.341863
# 2   2024-05-28    10526.85  10230.3385  133.593631    93.900484  75.571463
# 1   2024-05-29    10396.40  10257.8745  122.489392    99.618265  66.767226
# 0   2024-05-30    10205.24  10283.5305   97.144368    99.123486  57.155972
#
# [125 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Chuẩn hóa các cột giá dựa trên tập huấn luyện và áp dụng cho tập kiểm tra và kiểm định
scaler_price = MinMaxScaler(feature_range=(-1, 1))
price_columns = ['Close/Last', 'SMA', 'MACD', 'Signal_Line', 'RSI']
data_train_copy=data_train[price_columns]
data_train[price_columns] = scaler_price.fit_transform(data_train[price_columns])
data_val[price_columns] = scaler_price.transform(data_val[price_columns])
data_test_copy=data_test[price_columns]
data_test[price_columns] = scaler_price.transform(data_test[price_columns])

# Chuyển đổi các cột pandas thành mảng NumPy
train_data = data_train[price_columns].values
val_data = data_val[price_columns].values
test_data = data_test[price_columns].values

# Hiển thị kích thước của các tập dữ liệu
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))
# Out:
# Training data shape: (991, 5)
# Validation data shape: (123, 5)
# Test data shape: (125, 5)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16020\4175297681.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train[price_columns] = scaler_price.fit_transform(data_train[price_columns])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16020\4175297681.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_val[price_columns] = scaler_price.transform(data_val[price_columns])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16020\4175297681.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test[price_columns] = scaler_price.transform(data_test[price_columns])

# %%
# Training data
seq_len = 30
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(train_data[:, 0][i]) #Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 0][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 0][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print( X_train.shape, y_train.shape)
print( X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (961, 30, 5) (961,)
# (93, 30, 5) (93,)
# (95, 30, 5) (95,)

# %%
type(X_test)
# Out:
# numpy.ndarray

# %%
from tensorflow.keras.layers import LSTM, Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import Huber
from tensorflow.keras.metrics import MeanAbsoluteError
# model = Sequential([
#     LSTM(256),
#     Dropout(0.3),
#     LSTM(256),
#     Dropout(0.3),
#     Dense(1)
# ])
model = Sequential([
    LSTM(256, return_sequences=True),
    Dropout(0.3),
    LSTM(256),
    Dropout(0.3),
    Dense(1)
])
model.compile(optimizer=Adam(),
              loss=Huber(),
              metrics=[MeanAbsoluteError()])
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_val, y_val), verbose=1)


# Predicting and reversing normalization
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler_price.inverse_transform(np.concatenate((predicted_stock_price, np.zeros((len(predicted_stock_price), 4))), axis=1))[:,0]
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 165ms/step - loss: 0.0448 - mean_absolute_error: 0.2086 - val_loss: 0.0039 - val_mean_absolute_error: 0.0763
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0051 - mean_absolute_error: 0.0776 - val_loss: 0.0033 - val_mean_absolute_error: 0.0708
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0041 - mean_absolute_error: 0.0699 - val_loss: 0.0039 - val_mean_absolute_error: 0.0783
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0065 - mean_absolute_error: 0.0902 - val_loss: 0.0023 - val_mean_absolute_error: 0.0575
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0044 - mean_absolute_error: 0.0742 - val_loss: 0.0027 - val_mean_absolute_error: 0.0600
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 0.0043 - mean_absolute_error: 0.0693 - val_loss: 0.0045 - val_mean_absolute_error: 0.0761
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0049 - mean_absolute_error: 0.0767 - val_loss: 0.0021 - val_mean_absolute_error: 0.0545
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0036 - mean_absolute_error: 0.0661 - val_loss: 0.0025 - val_mean_absolute_error: 0.0610
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.0034 - mean_absolute_error: 0.0644 - val_loss: 0.0032 - val_mean_absolute_error: 0.0646
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0050 - mean_absolute_error: 0.0785 - val_loss: 0.0023 - val_mean_absolute_error: 0.0560
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0032 - mean_absolute_error: 0.0625 - val_loss: 0.0021 - val_mean_absolute_error: 0.0542
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0035 - mean_absolute_error: 0.0651 - val_loss: 0.0021 - val_mean_absolute_error: 0.0540
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0030 - mean_absolute_error: 0.0600 - val_loss: 0.0016 - val_mean_absolute_error: 0.0483
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0027 - mean_absolute_error: 0.0565 - val_loss: 0.0023 - val_mean_absolute_error: 0.0556
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0030 - mean_absolute_error: 0.0601 - val_loss: 0.0017 - val_mean_absolute_error: 0.0499
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0028 - mean_absolute_error: 0.0586 - val_loss: 0.0029 - val_mean_absolute_error: 0.0638
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.0045 - mean_absolute_error: 0.0722 - val_loss: 0.0024 - val_mean_absolute_error: 0.0591
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0034 - mean_absolute_error: 0.0642 - val_loss: 0.0018 - val_mean_absolute_error: 0.0498
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0030 - mean_absolute_error: 0.0602 - val_loss: 0.0020 - val_mean_absolute_error: 0.0523
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0028 - mean_absolute_error: 0.0586 - val_loss: 0.0013 - val_mean_absolute_error: 0.0447
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0040 - mean_absolute_error: 0.0706 - val_loss: 0.0019 - val_mean_absolute_error: 0.0514
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0034 - mean_absolute_error: 0.0655 - val_loss: 0.0016 - val_mean_absolute_error: 0.0466
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0027 - mean_absolute_error: 0.0576 - val_loss: 0.0015 - val_mean_absolute_error: 0.0455
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0023 - mean_absolute_error: 0.0525 - val_loss: 0.0013 - val_mean_absolute_error: 0.0432
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0030 - mean_absolute_error: 0.0604 - val_loss: 0.0030 - val_mean_absolute_error: 0.0631
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.0035 - mean_absolute_error: 0.0660 - val_loss: 0.0012 - val_mean_absolute_error: 0.0417
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0035 - mean_absolute_error: 0.0623 - val_loss: 0.0016 - val_mean_absolute_error: 0.0463
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0029 - mean_absolute_error: 0.0587 - val_loss: 0.0019 - val_mean_absolute_error: 0.0499
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0024 - mean_absolute_error: 0.0541 - val_loss: 0.0017 - val_mean_absolute_error: 0.0485
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0022 - mean_absolute_error: 0.0536 - val_loss: 0.0013 - val_mean_absolute_error: 0.0425
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0025 - mean_absolute_error: 0.0538 - val_loss: 0.0013 - val_mean_absolute_error: 0.0434
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0040 - mean_absolute_error: 0.0681 - val_loss: 0.0019 - val_mean_absolute_error: 0.0512
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.0046 - mean_absolute_error: 0.0726 - val_loss: 0.0026 - val_mean_absolute_error: 0.0610
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0036 - mean_absolute_error: 0.0661 - val_loss: 0.0015 - val_mean_absolute_error: 0.0467
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0031 - mean_absolute_error: 0.0628 - val_loss: 0.0018 - val_mean_absolute_error: 0.0505
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0025 - mean_absolute_error: 0.0554 - val_loss: 0.0014 - val_mean_absolute_error: 0.0432
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0025 - mean_absolute_error: 0.0556 - val_loss: 0.0012 - val_mean_absolute_error: 0.0399
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0026 - mean_absolute_error: 0.0548 - val_loss: 0.0013 - val_mean_absolute_error: 0.0423
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0023 - mean_absolute_error: 0.0537 - val_loss: 0.0012 - val_mean_absolute_error: 0.0416
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0025 - mean_absolute_error: 0.0559 - val_loss: 0.0012 - val_mean_absolute_error: 0.0423
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0029 - mean_absolute_error: 0.0588 - val_loss: 0.0019 - val_mean_absolute_error: 0.0506
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0030 - mean_absolute_error: 0.0609 - val_loss: 0.0013 - val_mean_absolute_error: 0.0396
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.0028 - mean_absolute_error: 0.0576 - val_loss: 0.0015 - val_mean_absolute_error: 0.0462
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.0029 - mean_absolute_error: 0.0601 - val_loss: 0.0015 - val_mean_absolute_error: 0.0444
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0025 - mean_absolute_error: 0.0551 - val_loss: 0.0011 - val_mean_absolute_error: 0.0380
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0021 - mean_absolute_error: 0.0510 - val_loss: 0.0011 - val_mean_absolute_error: 0.0385
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0020 - mean_absolute_error: 0.0499 - val_loss: 0.0011 - val_mean_absolute_error: 0.0387
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0027 - mean_absolute_error: 0.0577 - val_loss: 0.0014 - val_mean_absolute_error: 0.0426
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0021 - mean_absolute_error: 0.0508 - val_loss: 0.0014 - val_mean_absolute_error: 0.0438
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0026 - mean_absolute_error: 0.0564 - val_loss: 0.0011 - val_mean_absolute_error: 0.0369
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0020 - mean_absolute_error: 0.0496 - val_loss: 0.0012 - val_mean_absolute_error: 0.0402
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0023 - mean_absolute_error: 0.0535 - val_loss: 0.0013 - val_mean_absolute_error: 0.0430
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0021 - mean_absolute_error: 0.0496 - val_loss: 0.0013 - val_mean_absolute_error: 0.0426
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0021 - mean_absolute_error: 0.0500 - val_loss: 0.0036 - val_mean_absolute_error: 0.0753
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0042 - mean_absolute_error: 0.0691 - val_loss: 0.0019 - val_mean_absolute_error: 0.0510
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0023 - mean_absolute_error: 0.0537 - val_loss: 0.0014 - val_mean_absolute_error: 0.0426
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0036 - mean_absolute_error: 0.0647 - val_loss: 0.0024 - val_mean_absolute_error: 0.0599
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0056 - mean_absolute_error: 0.0842 - val_loss: 0.0030 - val_mean_absolute_error: 0.0652
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0030 - mean_absolute_error: 0.0597 - val_loss: 0.0017 - val_mean_absolute_error: 0.0455
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0025 - mean_absolute_error: 0.0532 - val_loss: 9.3286e-04 - val_mean_absolute_error: 0.0354
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0028 - mean_absolute_error: 0.0568 - val_loss: 0.0024 - val_mean_absolute_error: 0.0570
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0031 - mean_absolute_error: 0.0602 - val_loss: 0.0014 - val_mean_absolute_error: 0.0436
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0024 - mean_absolute_error: 0.0526 - val_loss: 0.0018 - val_mean_absolute_error: 0.0469
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0030 - mean_absolute_error: 0.0574 - val_loss: 0.0010 - val_mean_absolute_error: 0.0356
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0025 - mean_absolute_error: 0.0541 - val_loss: 0.0018 - val_mean_absolute_error: 0.0497
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0029 - mean_absolute_error: 0.0584 - val_loss: 0.0011 - val_mean_absolute_error: 0.0402
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0023 - mean_absolute_error: 0.0524 - val_loss: 0.0014 - val_mean_absolute_error: 0.0414
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0030 - mean_absolute_error: 0.0598 - val_loss: 0.0020 - val_mean_absolute_error: 0.0520
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0028 - mean_absolute_error: 0.0583 - val_loss: 0.0011 - val_mean_absolute_error: 0.0368
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0022 - mean_absolute_error: 0.0514 - val_loss: 0.0018 - val_mean_absolute_error: 0.0480
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0029 - mean_absolute_error: 0.0584 - val_loss: 0.0040 - val_mean_absolute_error: 0.0794
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0068 - mean_absolute_error: 0.0870 - val_loss: 0.0014 - val_mean_absolute_error: 0.0449
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0037 - mean_absolute_error: 0.0657 - val_loss: 0.0021 - val_mean_absolute_error: 0.0526
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0036 - mean_absolute_error: 0.0650 - val_loss: 0.0015 - val_mean_absolute_error: 0.0430
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0022 - mean_absolute_error: 0.0502 - val_loss: 0.0014 - val_mean_absolute_error: 0.0418
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0023 - mean_absolute_error: 0.0516 - val_loss: 0.0028 - val_mean_absolute_error: 0.0658
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0049 - mean_absolute_error: 0.0747 - val_loss: 0.0016 - val_mean_absolute_error: 0.0474
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0027 - mean_absolute_error: 0.0574 - val_loss: 0.0012 - val_mean_absolute_error: 0.0414
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0021 - mean_absolute_error: 0.0505 - val_loss: 0.0018 - val_mean_absolute_error: 0.0497
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0035 - mean_absolute_error: 0.0634 - val_loss: 0.0010 - val_mean_absolute_error: 0.0369
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0028 - mean_absolute_error: 0.0582 - val_loss: 0.0015 - val_mean_absolute_error: 0.0428
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0028 - mean_absolute_error: 0.0589 - val_loss: 0.0011 - val_mean_absolute_error: 0.0386
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0025 - mean_absolute_error: 0.0540 - val_loss: 0.0015 - val_mean_absolute_error: 0.0429
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0025 - mean_absolute_error: 0.0549 - val_loss: 0.0013 - val_mean_absolute_error: 0.0395
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0022 - mean_absolute_error: 0.0509 - val_loss: 0.0010 - val_mean_absolute_error: 0.0361
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0020 - mean_absolute_error: 0.0488 - val_loss: 9.6394e-04 - val_mean_absolute_error: 0.0359
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0023 - mean_absolute_error: 0.0525 - val_loss: 0.0013 - val_mean_absolute_error: 0.0422
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 0.0024 - mean_absolute_error: 0.0536 - val_loss: 0.0015 - val_mean_absolute_error: 0.0428
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0023 - mean_absolute_error: 0.0523 - val_loss: 0.0012 - val_mean_absolute_error: 0.0398
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0022 - mean_absolute_error: 0.0509 - val_loss: 9.8049e-04 - val_mean_absolute_error: 0.0361
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0021 - mean_absolute_error: 0.0502 - val_loss: 0.0013 - val_mean_absolute_error: 0.0410
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0030 - mean_absolute_error: 0.0598 - val_loss: 0.0010 - val_mean_absolute_error: 0.0349
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0025 - mean_absolute_error: 0.0552 - val_loss: 0.0016 - val_mean_absolute_error: 0.0444
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0021 - mean_absolute_error: 0.0506 - val_loss: 0.0011 - val_mean_absolute_error: 0.0388
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0020 - mean_absolute_error: 0.0493 - val_loss: 9.5409e-04 - val_mean_absolute_error: 0.0353
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - loss: 0.0022 - mean_absolute_error: 0.0512 - val_loss: 9.4085e-04 - val_mean_absolute_error: 0.0347
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0020 - mean_absolute_error: 0.0492 - val_loss: 0.0012 - val_mean_absolute_error: 0.0406
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.0020 - mean_absolute_error: 0.0484 - val_loss: 0.0010 - val_mean_absolute_error: 0.0373
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0019 - mean_absolute_error: 0.0479 - val_loss: 0.0013 - val_mean_absolute_error: 0.0393
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0024 - mean_absolute_error: 0.0525 - val_loss: 0.0021 - val_mean_absolute_error: 0.0514
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 220ms/step

# %%
predict = model.predict(X_test[0][np.newaxis, :, :])
predict = scaler_price.inverse_transform(np.concatenate((predict, np.zeros((len(predict), 4))), axis=1))[:,0]
predict
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# array([9736.31235359])

# %%
X_test[0][np.newaxis, :, :]
# Out:
# array([[[ 0.65493206,  0.53787171,  0.91301694,  0.95112871,
#           0.77364582],
#         [ 0.66470775,  0.55778835,  0.92020484,  0.97757445,
#           0.67809003],
#         [ 0.62655267,  0.5729229 ,  0.88997951,  0.99146846,
#           0.5120263 ],
#         [ 0.62012138,  0.58827885,  0.85389258,  0.99391264,
#           0.21769841],
#         [ 0.59878104,  0.59944499,  0.80276535,  0.98358305,
#           0.06986994],
#         [ 0.65374057,  0.61333526,  0.79601074,  0.97369637,
#           0.25427368],
#         [ 0.66749933,  0.62906438,  0.79408903,  0.96532528,
#           0.25362893],
#         [ 0.73906072,  0.64383131,  0.83807676,  0.96919784,
#           0.31671119],
#         [ 0.76970633,  0.66095589,  0.88773075,  0.98422683,
#           0.54296583],
#         [ 0.81314929,  0.67528516,  0.95057933,  1.01135138,
#           0.61074745],
#         [ 0.84523019,  0.69115685,  1.01477366,  1.04847573,
#           0.64377759],
#         [ 0.87241809,  0.70847107,  1.07572694,  1.09282117,
#           0.6998354 ],
#         [ 0.86946168,  0.72484109,  1.11149044,  1.13689082,
#           0.66154123],
#         [ 0.8830625 ,  0.73931063,  1.13917039,  1.17879753,
#           0.62021316],
#         [ 0.82453881,  0.75218913,  1.10766909,  1.20475371,
#           0.38390563],
#         [ 0.88592276,  0.76847093,  1.11749553,  1.22787977,
#           0.46554862],
#         [ 0.90081464,  0.78520531,  1.12572634,  1.24835833,
#           0.6424559 ],
#         [ 0.9335239 ,  0.80405105,  1.14559068,  1.26951421,
#           0.70326161],
#         [ 0.93295391,  0.82166075,  1.15010398,  1.28752338,
#           0.79730335],
#         [ 0.92960264,  0.83651341,  1.1405129 ,  1.29962615,
#           0.73352412],
#         [ 0.90814899,  0.85062586,  1.10679566,  1.30120674,
#           0.61113102],
#         [ 0.80481574,  0.85843444,  0.99492264,  1.27559019,
#           0.06752938],
#         [ 0.75863614,  0.8657958 ,  0.86471975,  1.22381159,
#          -0.14742014],
#         [ 0.74023847,  0.87249024,  0.74187486,  1.15287135,
#          -0.32679999],
#         [ 0.74825955,  0.88082107,  0.64543708,  1.07294694,
#          -0.41216461],
#         [ 0.83745633,  0.89106004,  0.62991268,  1.00527718,
#          -0.20974913],
#         [ 0.85436035,  0.90147429,  0.62530379,  0.95003394,
#          -0.1561173 ],
#         [ 0.87408686,  0.90899965,  0.63135524,  0.9072934 ,
#          -0.1401036 ],
#         [ 0.89137201,  0.9157804 ,  0.64391167,  0.87611805,
#           0.06754676],
#         [ 0.88969294,  0.92004638,  0.64760873,  0.85206611,
#          -0.10533147]]])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# Get actual prices from the last part of the test set
actual_prices = data_test_copy['Close/Last'].values[seq_len:]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(actual_prices, color='blue', label='Actual Stock Price')
plt.plot(predicted_stock_price, color='red', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# Calculate RMSE
rmse = mean_squared_error(actual_prices, predicted_stock_price, squared=False)
print(f"Root Mean Squared Error: {rmse}")

mape = mean_absolute_percentage_error(actual_prices, predicted_stock_price)
print(f"Mean Absolute Percentage Error: {mape}")
# Out:
# Root Mean Squared Error: 303.2752577496591
# Mean Absolute Percentage Error: 0.026432960691499002

# %%
predicted_stock_price_train = model.predict(X_train)
predicted_stock_price_train = scaler_price.inverse_transform(np.concatenate((predicted_stock_price_train, np.zeros((len(predicted_stock_price_train), 4))), axis=1))[:,0]
actual_train_prices = data_train_copy['Close/Last'].values[seq_len:]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(actual_train_prices, color='blue', label='Actual Stock Price')
plt.plot(predicted_stock_price_train, color='red', label='Predicted Stock Price')
plt.title('Technology Sector Stock Index Forecast')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step

# %%
# model.save('2_layerLSTMTechnical.h5')

# %%
import joblib 
# filename = 'predict_model.pkl'
# joblib.dump(model, open(filename, 'wb')) 
  
# # load the model 
# load_model = joblib.load(open(filename, 'rb'))

# %%
# joblib.dump(scaler_price, 'scaler_price_technical2lstm.pkl')

# %%
# np.save('X_test12.npy', X_test)
