# %% [markdown]
# ### LSTM - Input: 'Close/Last', 'Open', 'High', 'Low'

# %%
import pandas as pd
import numpy as np
# Load the data
data = pd.read_csv("Data_input_1.csv")

# Check for missing values
print(data.isnull().sum())

# Fill missing values or drop rows with missing values
data.fillna(method='ffill', inplace=True)  # forward fill
data.dropna(inplace=True)  # drop any remaining NaNs
# Out:
# Date          0
# Close/Last    0
# Open          0
# High          0
# Low           0
# dtype: int64
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24168\4277517028.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)  # forward fill

# %%
data['Date'] = pd.to_datetime(data['Date'])

# Tạo các cột phụ để sắp xếp theo năm, tháng, ngày
data['Year'] = data['Date'].dt.year
data['Month'] = data['Date'].dt.month
data['Day'] = data['Date'].dt.day

# Sắp xếp DataFrame theo năm, sau đó tháng, và cuối cùng là ngày
data.sort_values(['Year', 'Month', 'Day'], inplace=True)

# Xóa các cột phụ nếu không cần thiết
data.drop(columns=['Year', 'Month', 'Day'], inplace=True)
data
# Out:
#            Date  Close/Last      Open      High       Low
# 1257 2019-06-03     4170.02   4255.18   4264.98   4145.45
# 1256 2019-06-04     4320.98   4230.68   4322.79   4199.29
# 1255 2019-06-05     4329.21   4359.99   4372.12   4279.17
# 1254 2019-06-06     4375.45   4338.55   4388.83   4321.69
# 1253 2019-06-07     4435.80   4398.04   4453.16   4390.15
# ...         ...         ...       ...       ...       ...
# 4    2024-05-23    10495.82  10698.18  10704.39  10444.49
# 3    2024-05-24    10549.22  10494.50  10616.85  10480.60
# 2    2024-05-28    10526.85  10592.65  10594.29  10462.57
# 1    2024-05-29    10396.40  10386.55  10451.02  10386.55
# 0    2024-05-30    10205.24  10332.57  10348.39  10174.34
#
# [1258 rows x 5 columns]

# %%
# Tính toán số lượng dòng cho từng phần
total_rows = len(data)
train_size = int(0.8 * total_rows)
val_size = int(0.1 * total_rows)
test_size = total_rows - train_size - val_size  # Đảm bảo rằng tổng số dòng vẫn bằng total_rows

# Chia DataFrame thành các tập huấn luyện, kiểm tra và kiểm định
data_train = data.iloc[:train_size]
data_val = data.iloc[train_size:train_size + val_size]
data_test = data.iloc[train_size + val_size:]

# %%
data_test
# Out:
#           Date  Close/Last      Open      High       Low
# 126 2023-11-28     8739.96   8661.84   8753.15   8661.15
# 125 2023-11-29     8874.27   8872.32   8963.51   8863.59
# 124 2023-11-30     8850.47   8898.31   8924.81   8765.49
# 123 2023-12-01     8878.94   8797.75   8883.24   8759.92
# 122 2023-12-04     8767.82   8785.59   8791.24   8637.88
# ..         ...         ...       ...       ...       ...
# 4   2024-05-23    10495.82  10698.18  10704.39  10444.49
# 3   2024-05-24    10549.22  10494.50  10616.85  10480.60
# 2   2024-05-28    10526.85  10592.65  10594.29  10462.57
# 1   2024-05-29    10396.40  10386.55  10451.02  10386.55
# 0   2024-05-30    10205.24  10332.57  10348.39  10174.34
#
# [127 rows x 5 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Chuẩn hóa các cột giá dựa trên tập huấn luyện và áp dụng cho tập kiểm tra và kiểm định
scaler_price = MinMaxScaler(feature_range=(-1, 1))
price_columns = ['Close/Last', 'Open', 'High', 'Low']
data_train_copy=data_train[price_columns]
data_train[price_columns] = scaler_price.fit_transform(data_train[price_columns])
data_val[price_columns] = scaler_price.transform(data_val[price_columns])
data_test_copy=data_test[price_columns]
data_test[price_columns] = scaler_price.transform(data_test[price_columns])

# Chuyển đổi các cột pandas thành mảng NumPy
train_data = data_train[price_columns].values
val_data = data_val[price_columns].values
test_data = data_test[price_columns].values

# Hiển thị kích thước của các tập dữ liệu
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))
# Out:
# Training data shape: (1006, 4)
# Validation data shape: (125, 4)
# Test data shape: (127, 4)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24168\447585929.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train[price_columns] = scaler_price.fit_transform(data_train[price_columns])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24168\447585929.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_val[price_columns] = scaler_price.transform(data_val[price_columns])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24168\447585929.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test[price_columns] = scaler_price.transform(data_test[price_columns])

# %%
# Training data
seq_len = 30
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(train_data[:, 0][i]) #Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 0][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 0][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print( X_train.shape, y_train.shape)
print( X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (976, 30, 4) (976,)
# (95, 30, 4) (95,)
# (97, 30, 4) (97,)

# %%
type(X_test)
# Out:
# numpy.ndarray

# %%
from tensorflow.keras.layers import LSTM, Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import Huber
from tensorflow.keras.metrics import MeanAbsoluteError


# model = Sequential([
#     LSTM(256),
#     Dropout(0.3),
#     LSTM(256),
#     Dropout(0.3),
#     Dense(1)
# ])
model = Sequential([
    LSTM(256, return_sequences=True),
    Dropout(0.3),
    LSTM(256),
    Dropout(0.3),
    Dense(1)
])
model.compile(optimizer=Adam(),
              loss=Huber(),
              metrics=[MeanAbsoluteError()])
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_val, y_val), verbose=1)

# Predicting and reversing normalization
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler_price.inverse_transform(np.concatenate((predicted_stock_price, np.zeros((len(predicted_stock_price), 3))), axis=1))[:,0]
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 148ms/step - loss: 0.0428 - mean_absolute_error: 0.2140 - val_loss: 0.0041 - val_mean_absolute_error: 0.0780
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0052 - mean_absolute_error: 0.0823 - val_loss: 0.0034 - val_mean_absolute_error: 0.0706
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0041 - mean_absolute_error: 0.0706 - val_loss: 0.0035 - val_mean_absolute_error: 0.0701
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 0.0036 - mean_absolute_error: 0.0673 - val_loss: 0.0029 - val_mean_absolute_error: 0.0650
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0032 - mean_absolute_error: 0.0624 - val_loss: 0.0027 - val_mean_absolute_error: 0.0633
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0032 - mean_absolute_error: 0.0623 - val_loss: 0.0026 - val_mean_absolute_error: 0.0611
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0034 - mean_absolute_error: 0.0641 - val_loss: 0.0024 - val_mean_absolute_error: 0.0606
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 0.0034 - mean_absolute_error: 0.0637 - val_loss: 0.0024 - val_mean_absolute_error: 0.0583
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 0.0032 - mean_absolute_error: 0.0619 - val_loss: 0.0022 - val_mean_absolute_error: 0.0571
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0028 - mean_absolute_error: 0.0567 - val_loss: 0.0021 - val_mean_absolute_error: 0.0549
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 0.0026 - mean_absolute_error: 0.0549 - val_loss: 0.0021 - val_mean_absolute_error: 0.0548
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - loss: 0.0027 - mean_absolute_error: 0.0579 - val_loss: 0.0019 - val_mean_absolute_error: 0.0530
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0029 - mean_absolute_error: 0.0596 - val_loss: 0.0019 - val_mean_absolute_error: 0.0523
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0025 - mean_absolute_error: 0.0556 - val_loss: 0.0018 - val_mean_absolute_error: 0.0508
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0030 - mean_absolute_error: 0.0603 - val_loss: 0.0019 - val_mean_absolute_error: 0.0510
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0026 - mean_absolute_error: 0.0561 - val_loss: 0.0017 - val_mean_absolute_error: 0.0492
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0027 - mean_absolute_error: 0.0569 - val_loss: 0.0017 - val_mean_absolute_error: 0.0492
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0026 - mean_absolute_error: 0.0562 - val_loss: 0.0015 - val_mean_absolute_error: 0.0472
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 0.0025 - mean_absolute_error: 0.0550 - val_loss: 0.0019 - val_mean_absolute_error: 0.0509
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0026 - mean_absolute_error: 0.0562 - val_loss: 0.0015 - val_mean_absolute_error: 0.0463
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0026 - mean_absolute_error: 0.0557 - val_loss: 0.0014 - val_mean_absolute_error: 0.0456
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0028 - mean_absolute_error: 0.0575 - val_loss: 0.0014 - val_mean_absolute_error: 0.0453
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0025 - mean_absolute_error: 0.0546 - val_loss: 0.0015 - val_mean_absolute_error: 0.0460
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.0024 - mean_absolute_error: 0.0538 - val_loss: 0.0014 - val_mean_absolute_error: 0.0449
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 0.0025 - mean_absolute_error: 0.0551 - val_loss: 0.0015 - val_mean_absolute_error: 0.0456
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0024 - mean_absolute_error: 0.0533 - val_loss: 0.0013 - val_mean_absolute_error: 0.0438
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0025 - mean_absolute_error: 0.0539 - val_loss: 0.0016 - val_mean_absolute_error: 0.0471
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0026 - mean_absolute_error: 0.0552 - val_loss: 0.0013 - val_mean_absolute_error: 0.0425
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0025 - mean_absolute_error: 0.0527 - val_loss: 0.0012 - val_mean_absolute_error: 0.0419
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0021 - mean_absolute_error: 0.0510 - val_loss: 0.0012 - val_mean_absolute_error: 0.0408
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0026 - mean_absolute_error: 0.0552 - val_loss: 0.0014 - val_mean_absolute_error: 0.0441
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 0.0023 - mean_absolute_error: 0.0538 - val_loss: 0.0012 - val_mean_absolute_error: 0.0407
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0022 - mean_absolute_error: 0.0513 - val_loss: 0.0012 - val_mean_absolute_error: 0.0408
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 0.0022 - mean_absolute_error: 0.0510 - val_loss: 0.0012 - val_mean_absolute_error: 0.0405
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 0.0023 - mean_absolute_error: 0.0523 - val_loss: 0.0011 - val_mean_absolute_error: 0.0394
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0021 - mean_absolute_error: 0.0513 - val_loss: 0.0012 - val_mean_absolute_error: 0.0399
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.0024 - mean_absolute_error: 0.0530 - val_loss: 0.0014 - val_mean_absolute_error: 0.0444
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.0020 - mean_absolute_error: 0.0502 - val_loss: 0.0011 - val_mean_absolute_error: 0.0394
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0020 - mean_absolute_error: 0.0495 - val_loss: 0.0011 - val_mean_absolute_error: 0.0394
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0020 - mean_absolute_error: 0.0486 - val_loss: 0.0011 - val_mean_absolute_error: 0.0382
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0019 - mean_absolute_error: 0.0479 - val_loss: 0.0011 - val_mean_absolute_error: 0.0390
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0019 - mean_absolute_error: 0.0477 - val_loss: 0.0011 - val_mean_absolute_error: 0.0393
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0022 - mean_absolute_error: 0.0508 - val_loss: 0.0010 - val_mean_absolute_error: 0.0369
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - loss: 0.0019 - mean_absolute_error: 0.0476 - val_loss: 0.0011 - val_mean_absolute_error: 0.0375
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.0021 - mean_absolute_error: 0.0492 - val_loss: 0.0011 - val_mean_absolute_error: 0.0377
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.0021 - mean_absolute_error: 0.0503 - val_loss: 0.0012 - val_mean_absolute_error: 0.0406
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0020 - mean_absolute_error: 0.0497 - val_loss: 0.0011 - val_mean_absolute_error: 0.0376
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0021 - mean_absolute_error: 0.0506 - val_loss: 9.8070e-04 - val_mean_absolute_error: 0.0356
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0017 - mean_absolute_error: 0.0455 - val_loss: 0.0011 - val_mean_absolute_error: 0.0381
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0019 - mean_absolute_error: 0.0482 - val_loss: 9.9153e-04 - val_mean_absolute_error: 0.0355
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0019 - mean_absolute_error: 0.0492 - val_loss: 0.0010 - val_mean_absolute_error: 0.0377
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0018 - mean_absolute_error: 0.0470 - val_loss: 0.0010 - val_mean_absolute_error: 0.0356
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0020 - mean_absolute_error: 0.0482 - val_loss: 9.5449e-04 - val_mean_absolute_error: 0.0350
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 0.0018 - mean_absolute_error: 0.0463 - val_loss: 0.0011 - val_mean_absolute_error: 0.0390
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0022 - mean_absolute_error: 0.0508 - val_loss: 0.0012 - val_mean_absolute_error: 0.0389
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0018 - mean_absolute_error: 0.0461 - val_loss: 0.0011 - val_mean_absolute_error: 0.0380
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 0.0019 - mean_absolute_error: 0.0475 - val_loss: 0.0011 - val_mean_absolute_error: 0.0375
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0019 - mean_absolute_error: 0.0485 - val_loss: 0.0011 - val_mean_absolute_error: 0.0383
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.0018 - mean_absolute_error: 0.0477 - val_loss: 9.2890e-04 - val_mean_absolute_error: 0.0338
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0019 - mean_absolute_error: 0.0474 - val_loss: 0.0010 - val_mean_absolute_error: 0.0374
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.0018 - mean_absolute_error: 0.0480 - val_loss: 9.1977e-04 - val_mean_absolute_error: 0.0341
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0020 - mean_absolute_error: 0.0478 - val_loss: 9.3354e-04 - val_mean_absolute_error: 0.0336
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - loss: 0.0018 - mean_absolute_error: 0.0472 - val_loss: 9.2108e-04 - val_mean_absolute_error: 0.0343
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0020 - mean_absolute_error: 0.0486 - val_loss: 8.9488e-04 - val_mean_absolute_error: 0.0338
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0020 - mean_absolute_error: 0.0501 - val_loss: 9.1753e-04 - val_mean_absolute_error: 0.0341
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0020 - mean_absolute_error: 0.0482 - val_loss: 0.0012 - val_mean_absolute_error: 0.0411
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.0017 - mean_absolute_error: 0.0446 - val_loss: 0.0011 - val_mean_absolute_error: 0.0363
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0020 - mean_absolute_error: 0.0482 - val_loss: 9.8952e-04 - val_mean_absolute_error: 0.0365
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0017 - mean_absolute_error: 0.0456 - val_loss: 9.1537e-04 - val_mean_absolute_error: 0.0332
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0018 - mean_absolute_error: 0.0469 - val_loss: 8.9042e-04 - val_mean_absolute_error: 0.0334
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0018 - mean_absolute_error: 0.0474 - val_loss: 8.7779e-04 - val_mean_absolute_error: 0.0328
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0017 - mean_absolute_error: 0.0445 - val_loss: 8.6369e-04 - val_mean_absolute_error: 0.0325
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0020 - mean_absolute_error: 0.0489 - val_loss: 8.6614e-04 - val_mean_absolute_error: 0.0320
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.0019 - mean_absolute_error: 0.0480 - val_loss: 8.8043e-04 - val_mean_absolute_error: 0.0333
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0019 - mean_absolute_error: 0.0481 - val_loss: 9.0795e-04 - val_mean_absolute_error: 0.0341
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0017 - mean_absolute_error: 0.0454 - val_loss: 9.3626e-04 - val_mean_absolute_error: 0.0336
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0020 - mean_absolute_error: 0.0475 - val_loss: 0.0010 - val_mean_absolute_error: 0.0380
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0018 - mean_absolute_error: 0.0471 - val_loss: 8.6480e-04 - val_mean_absolute_error: 0.0320
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0020 - mean_absolute_error: 0.0479 - val_loss: 9.7429e-04 - val_mean_absolute_error: 0.0363
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0018 - mean_absolute_error: 0.0460 - val_loss: 0.0010 - val_mean_absolute_error: 0.0382
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0018 - mean_absolute_error: 0.0470 - val_loss: 9.0961e-04 - val_mean_absolute_error: 0.0331
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0019 - mean_absolute_error: 0.0469 - val_loss: 8.8468e-04 - val_mean_absolute_error: 0.0336
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.0019 - mean_absolute_error: 0.0475 - val_loss: 9.3699e-04 - val_mean_absolute_error: 0.0355
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0020 - mean_absolute_error: 0.0484 - val_loss: 8.4876e-04 - val_mean_absolute_error: 0.0316
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.0018 - mean_absolute_error: 0.0466 - val_loss: 8.8875e-04 - val_mean_absolute_error: 0.0337
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0017 - mean_absolute_error: 0.0440 - val_loss: 8.9692e-04 - val_mean_absolute_error: 0.0341
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0018 - mean_absolute_error: 0.0470 - val_loss: 9.3340e-04 - val_mean_absolute_error: 0.0334
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0018 - mean_absolute_error: 0.0462 - val_loss: 8.6166e-04 - val_mean_absolute_error: 0.0318
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0016 - mean_absolute_error: 0.0428 - val_loss: 8.4160e-04 - val_mean_absolute_error: 0.0320
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0016 - mean_absolute_error: 0.0442 - val_loss: 9.2793e-04 - val_mean_absolute_error: 0.0352
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0018 - mean_absolute_error: 0.0456 - val_loss: 8.3867e-04 - val_mean_absolute_error: 0.0315
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0017 - mean_absolute_error: 0.0462 - val_loss: 0.0015 - val_mean_absolute_error: 0.0475
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.0021 - mean_absolute_error: 0.0505 - val_loss: 8.3437e-04 - val_mean_absolute_error: 0.0311
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 0.0018 - mean_absolute_error: 0.0471 - val_loss: 9.4613e-04 - val_mean_absolute_error: 0.0360
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0019 - mean_absolute_error: 0.0469 - val_loss: 8.7995e-04 - val_mean_absolute_error: 0.0337
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.0019 - mean_absolute_error: 0.0466 - val_loss: 8.3890e-04 - val_mean_absolute_error: 0.0323
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.0018 - mean_absolute_error: 0.0458 - val_loss: 8.5045e-04 - val_mean_absolute_error: 0.0317
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.0017 - mean_absolute_error: 0.0460 - val_loss: 8.6976e-04 - val_mean_absolute_error: 0.0321
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0017 - mean_absolute_error: 0.0452 - val_loss: 8.2523e-04 - val_mean_absolute_error: 0.0320
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - loss: 0.0016 - mean_absolute_error: 0.0439 - val_loss: 9.3368e-04 - val_mean_absolute_error: 0.0356
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 415ms/step

# %%
predict = model.predict(X_test[0][np.newaxis, :, :])
predict = scaler_price.inverse_transform(np.concatenate((predict, np.zeros((len(predict), 3))), axis=1))[:,0]
predict
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# array([9365.10583835])

# %%
X_test[0][np.newaxis, :, :]
# Out:
# array([[[0.61698643, 0.57924702, 0.59221692, 0.60360263],
#         [0.66310422, 0.65143725, 0.66530185, 0.67186515],
#         [0.65493206, 0.66035128, 0.65185639, 0.63878595],
#         [0.66470775, 0.62586131, 0.63741382, 0.63690775],
#         [0.62655267, 0.62169068, 0.60545045, 0.59575602],
#         [0.62012138, 0.58908366, 0.59143868, 0.60508293],
#         [0.59878104, 0.63500513, 0.61892718, 0.60992511],
#         [0.65374057, 0.60618803, 0.6299997 , 0.62325795],
#         [0.66749933, 0.62469175, 0.64554363, 0.64732045],
#         [0.73906072, 0.67154269, 0.71957704, 0.69357063],
#         [0.76970633, 0.71846222, 0.74287556, 0.73861701],
#         [0.81314929, 0.76571444, 0.79482298, 0.772347  ],
#         [0.84523019, 0.82308798, 0.83885252, 0.82489606],
#         [0.87241809, 0.85360625, 0.86719568, 0.86610512],
#         [0.86946168, 0.85955351, 0.85089089, 0.85923638],
#         [0.8830625 , 0.86035951, 0.86170285, 0.88021014],
#         [0.82453881, 0.85470722, 0.86420433, 0.83360927],
#         [0.88592276, 0.8611415 , 0.86339135, 0.86558246],
#         [0.90081464, 0.89632772, 0.88319126, 0.88734864],
#         [0.9335239 , 0.90082075, 0.91378229, 0.9187587 ],
#         [0.93295391, 0.92963785, 0.92016802, 0.92999754],
#         [0.92960264, 0.92867408, 0.91490448, 0.93568945],
#         [0.90814899, 0.91379222, 0.90803583, 0.90140646],
#         [0.80481574, 0.84832438, 0.83854678, 0.79596778],
#         [0.75863614, 0.74373292, 0.75435457, 0.76437225],
#         [0.74023847, 0.71815697, 0.73661838, 0.74040417],
#         [0.74825955, 0.72849093, 0.7466382 , 0.74833171],
#         [0.83745633, 0.75754468, 0.81168713, 0.77884482],
#         [0.85436035, 0.797831  , 0.84217393, 0.81864439],
#         [0.87408686, 0.84944935, 0.8561718 , 0.84386686]]])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# Get actual prices from the last part of the test set
actual_prices = data_test_copy['Close/Last'].values[seq_len:]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(actual_prices, color='blue', label='Actual Stock Price')
plt.plot(predicted_stock_price, color='red', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# Calculate RMSE
rmse = mean_squared_error(actual_prices, predicted_stock_price, squared=False)
print(f"Root Mean Squared Error: {rmse}")

mape = mean_absolute_percentage_error(actual_prices, predicted_stock_price)
print(f"Mean Absolute Percentage Error: {mape}")
# Out:
# Root Mean Squared Error: 202.3773131203521
# Mean Absolute Percentage Error: 0.016645190151026286

# %%
predicted_stock_price_train = model.predict(X_train)
predicted_stock_price_train = scaler_price.inverse_transform(np.concatenate((predicted_stock_price_train, np.zeros((len(predicted_stock_price_train), 3))), axis=1))[:,0]
actual_train_prices = data_train_copy['Close/Last'].values[seq_len:]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(actual_train_prices, color='blue', label='Actual Stock Price')
plt.plot(predicted_stock_price_train, color='red', label='Predicted Stock Price')
plt.title('Technology Sector Stock Index Forecast')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step

# %%
# model.save('2_layerLSTMMain.h5')

# %%
import joblib

# %%
# joblib.dump(scaler_price, 'scaler_price_main2lstm.pkl')

# %%
# np.save('X_test12.npy', X_test)
